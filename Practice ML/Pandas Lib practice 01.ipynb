# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=['A','B','C','D'])
pd.plotting.scatter_matrix(df, alpha=0.2)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FA7E40BD08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FA7E4341C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FA7E467C48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FA7E4A9EC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001FA7E4D8E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FA7E510F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FA7E550088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FA7E589188>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001FA7E594648>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FA7E5CB808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FA7E6314C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FA7E66B588>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001FA7E6A36C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FA7E6DA7C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FA7E7158C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FA7E74CA08>]],
#       dtype=object)

# %%
df = pd.DataFrame([[5.1, 3.5, 0], [4.9, 3.0, 0], [7.0, 3.2, 1],
                   [6.4, 3.2, 1], [5.9, 3.0, 2]],
                  columns=['length', 'width', 'species'])
ax1 = df.plot.scatter(x='length',
                      y='width',
                      c='DarkBlue')

# %%
ax2 = df.plot.scatter(x='length',
                      y='width',
                      c='species',
                      colormap='viridis')

# %%
plot = df.plot.pie(y='length', figsize=(5, 5))

# %%
plot = df.plot.pie(y='species', figsize=(5, 5))
